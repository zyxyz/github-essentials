# %%
# %load_ext watermark
# %watermark -v -p sklearn,numpy,scipy,matplotlib

# %%
# %matplotlib inline
from preamble import *

# %% [markdown]
# ## 지도 학습
# ### 분류와 회귀

# %% [raw]
# * 분류
#   : 미리 정의된, 가능성 있는 여러 클래스 레이블 중 하나를 예측
#
#   - 이진 분류(Binary Classification)
#     : 예/아니오
#     : 양성/음성 클래스 -> 양성 클래스: 학습하고자 하는 대상
#       예) 스팸 메일 분류
#
#   - 다중 분류(Multiclass Classification)
#       예) 붓꽃 분류, 웹사이트 글로부터 언어 예측, 손글씨 읽기 등
#
# * 회귀
#   : 연속적인 숫자, 부동소수점수(실수)를 예측하는 것
#
#     예) 어떤 사람의 교육 수준, 나이, 주거지 ==> 연간 소득 예측
#         농장에서 전년도 수확량, 날씨, 고용 인원수 ==> 올해 수확량 예측

# %% [markdown]
# ### 일반화, 과대적합, 과소적합

# %% [raw]
# * 일반화
#   : 모델이 처음 보는 데이터에 대해 정확하게 예측할 수 있음
#   : '훈련 세트에서 테스틑 세트로 일반화되었다'
#
# * 과(대)적합(Overfitting)
#   : 가진 정보를 모두 사용하여 너무 복잡한 모델 구축
#     - 주어진 훈련 데이터에만 너무나 맞추어져 있음
#     - 새로운 데이터에 일반화되기 어려움
#
# * 과소적합(Underfitting)
#   : 모델이 너무 간단하여 데이터의 성질과 다양성을 묘사하지 못하는 경우
#     - 아무 데이터에도 잘 맞거나 안맞음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### 모델 복잡도와 데이터셋 사이즈의 관계

# %% [raw]
# * 다양항 데이터 포인트가 많을수록 과대적합 없이 더 복잡한 모델 생성 가능
#   - 많은 데이터 포인트 ==> 다양성 증가
#   - 일반적, 큰 데이터 셋 ==> 복잡한 모델 가능
#
# * 같은 데이터 포인트 중복, 매우 비슷한 많은 데이터는 도움이 되지 않는다

# %% [markdown]
# ### 지도 학습 알고리즘
#
# #### 예제에 사용할 데이터 셋

# %% [raw]
# * Forge
#   : 이진 분류용 소규모 데이터 셋

# %%
plt.rcParams['figure.dpi'] = 300
# 데이터셋을 만듭니다
X, y = mglearn.datasets.make_forge()
# 산점도를 그립니다
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(["클래스 0", "클래스 1"], loc=4)
plt.xlabel("첫 번째 특성")
plt.ylabel("두 번째 특성")
print("X.shape: {}".format(X.shape))

# %% [raw]
# * Wave
#   : 회귀 알고리즘 설명용 소규모 데이터 셋

# %%
X, y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(X, y, 'o')
plt.ylim(-3, 3)
plt.xlabel("특성")
plt.ylabel("타깃")

# %% [raw]
# * 위스콘신 유방암(Wisconsin Breast Cancer) 데이터 셋
#   : scikit-learn 제공
#   : 분류용 실제 데이터 셋
#     - 양성(benign)
#     - 악성(malignant)

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
print("cancer.keys(): {}".format(cancer.keys()))

# %%
print("유방암 데이터의 형태: {}".format(cancer.data.shape))

# %%
print("클래스별 샘플 갯수:\n{}".format(
      {n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))}))

# %%
print("특성 이름:\n{}".format(cancer.feature_names))

# %% [raw]
# * 보스턴 주택가격(Boston Housing) 데이터 셋
#   : scikit-learn 제공
#   : 회귀분석용 실제 데이터 셋
#     - 범죄율, 찰스강 인접도, 고속도로 접근성 등을 이용하여 1970년대 보스턴 주변의 주택 평균 가격 예측

# %%
from sklearn.datasets import load_boston
boston = load_boston()
print("데이터의 형태: {}".format(boston.data.shape))

# %% [raw]
# * 보스턴 주택가격 데이터 셋의 확장
#   : 13개의 기본 특징 + 기본 특징끼리 곱으로 만든 91개의 특징
#     ==> 총 104개의 특징

# %%
X, y = mglearn.datasets.load_extended_boston()
print("X.shape: {}".format(X.shape))

# %% [markdown]
# ### k-최근접 이웃
# #### k-최근접 이웃 분류

# %% [raw]
# * 1-NN
#   : 가장 가까운 이웃(데이터 포인트) 하나

# %%
mglearn.plots.plot_knn_classification(n_neighbors=1)

# %% [raw]
# * 3-NN

# %%
mglearn.plots.plot_knn_classification(n_neighbors=3)

# %% [raw]
# * 이진 분류 뿐만 아니라 다분류 문제에도 같은 방법 적용

# %% [markdown]
# ### scikit-learn을 이용한 k-NN 적용

# %% [raw]
# * 일반화 성능 평가
#   : 데이터를 훈련 세트와 테스트 세트로 나눔

# %%
from sklearn.model_selection import train_test_split
X, y = mglearn.datasets.make_forge()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %% [raw]
# * k-NN 객체 생성

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier(n_neighbors=3)

# %% [raw]
# * 훈련 세트 이용하여 분류 모델 학습

# %%
clf.fit(X_train, y_train)

# %%
print("테스트 세트 예측: {}".format(clf.predict(X_test)))

# %%
print("테스트 세트 정확도: {:.2f}".format(clf.score(X_test, y_test)))

# %% [markdown]
# #### KNeighborsClassifier 분석

# %% [raw]
# * 모든 테스트 포인트의 예측 결과를 평면에 그림
# * 결정 경계(decision bounday)

# %%
fig, axes = plt.subplots(1, 3, figsize=(10, 3))

for n_neighbors, ax in zip([1, 3, 9], axes):
    # fit 메소드는 self 오브젝트를 리턴합니다
    # 그래서 객체 생성과 fit 메소드를 한 줄에 쓸 수 있습니다
    clf = KNeighborsClassifier(n_neighbors=n_neighbors).fit(X, y)
    mglearn.plots.plot_2d_separator(clf, X, fill=True, eps=0.5, ax=ax, alpha=.4)
    mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)
    ax.set_title("{} 이웃".format(n_neighbors))
    ax.set_xlabel("특성 0")
    ax.set_ylabel("특성 1")
axes[0].legend(loc=3)

# %% [raw]
# * 1-NN인 경우
#   - 결정 경계가 훈련 데이터에 가깝게 그려짐
#
# * 이웃 수를 늘릴수록 결정 경계가 부드러워짐
#   ==> 더 단순한 모델
#
# * 이웃을 적게 사용 -> 모델의 복잡도 증가
#          많이 사용 ->               감소

# %% [raw]
# * 모델의 복잡도와 일반화 사이의 관계 확인
#   : 유방암 데이터 셋을 이용
#   : 이웃의 수를 달리하여 훈련 셋과 데이터 셋의 성능 평가

# %% [raw]
# * train_test_split
#   - stratify 옵션
#     : 훈련 셋과 테스트 셋의 클래스 레이블이 옵션에 입력되는 배열의 클래스 레이블과
#       비슷한 비율이 되도록
#     : 옵션 입력 데이터의 0 비율이 25%, 1의 비율이 75%면
#       훈련 셋과 테스트 셋의 타깃의 0의 비율도 25%, 1의 비율도 75%가 되도록

# %%
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=66)

training_accuracy = []
test_accuracy = []
# 1 에서 10 까지 n_neighbors 를 적용
neighbors_settings = range(1, 11)

for n_neighbors in neighbors_settings:
    # 모델 생성
    clf = KNeighborsClassifier(n_neighbors=n_neighbors)
    clf.fit(X_train, y_train)
    # 훈련 세트 정확도 저장
    training_accuracy.append(clf.score(X_train, y_train))
    # 일반화 정확도 저장
    test_accuracy.append(clf.score(X_test, y_test))
    
plt.plot(neighbors_settings, training_accuracy, label="훈련 정확도")
plt.plot(neighbors_settings, test_accuracy, label="테스트 정확도")
plt.ylabel("정확도")
plt.xlabel("n_neighbors")
plt.legend()

# %% [raw]
# * 이웃이 1
#   : 모델이 너무 복잡
#     - 훈련 셋에 대한 예측은 완벽/정확(정확도: 1)
#     - 과대적합
#     - 테스트 셋에 대한 예측 정확도는 많이 낮음
#
# * 이웃이 10
#   : 모델이 너무 단순 -> 정확도 하락
#     - 과소적합
#
# * 이웃이 6
#   : 모델이 적당히 복잡, 단순
#     - 훈련 셋에 대한 예측 정확도는 낮아졌지만
#     - 테스트 셋에 대한 예측 정확도는 가장 좋음

# %% [markdown]
# #### k-Neighbors Regression

# %% [raw]
# * k-NN 알고리즘을 회귀 분석에 사용
#   - 1-NN: 가장 가까운 이웃의 타깃값
#   - 둘 이상의 이웃: 이웃 간의 평균(산술 평균 또는 가중 평균)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %%
from sklearn.neighbors import KNeighborsRegressor

X, y = mglearn.datasets.make_wave(n_samples=40)

# wave 데이터셋을 훈련 세트와 테스트 세트로 나눕니다
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# 이웃의 수를 3으로 하여 모델의 객체를 만듭니다
reg = KNeighborsRegressor(n_neighbors=3)
# 훈련 데이터와 타깃을 사용하여 모델을 학습시킵니다
reg.fit(X_train, y_train)

# %%
print("테스트 세트 예측:\n{}".format(reg.predict(X_test)))

# %%
print("테스트 세트 R^2: {:.2f}".format(reg.score(X_test, y_test)))

# %% [raw]
# * 결정 계수: R^2
#   : 회귀 모델에서 예측의 적합도를 0과 1 사이의 값으로 계산한 것

# %% [markdown]
# #### KNeighborsRegressor 분석

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
# -3 과 3 사이에 1,000 개의 데이터 포인트를 만듭니다
line = np.linspace(-3, 3, 1000).reshape(-1, 1)
for n_neighbors, ax in zip([1, 3, 9], axes):
    # 1, 3, 9 이웃을 사용한 예측을 합니다
    reg = KNeighborsRegressor(n_neighbors=n_neighbors)
    reg.fit(X_train, y_train)
    ax.plot(line, reg.predict(line))
    ax.plot(X_train, y_train, '^', c=mglearn.cm2(0), markersize=8)
    ax.plot(X_test, y_test, 'v', c=mglearn.cm2(1), markersize=8)

    ax.set_title(
        "{} 이웃의 훈련 스코어: {:.2f} 테스트 스코어: {:.2f}".format(
            n_neighbors, reg.score(X_train, y_train), reg.score(X_test, y_test)))
    ax.set_xlabel("특성")
    ax.set_ylabel("타깃")
axes[0].legend(["모델 예측", "훈련 데이터/타깃", "테스트 데이터/타깃"], loc="best")

# %% [markdown]
# #### 장단점과 매개변수

# %% [raw]
# * KNeighbors 분류기에서 중요한 두 개의 변수
#   1. 데이터 포인트 사이의 거리 측정 방법
#   2. 이웃의 수
#
# * 유클리드 거리 측정 방식 사용하려면
#   - 모델 생성 시 metric='minkowsk'이면서 p=2
#
# * 장점
#   - 이해하기 쉬운 모델
#   - 많이 조정하지 않아도 자주 좋은 성능 발휘
#   - 더 복잡한 알고리즘을 적용해보기 전에 시도해볼 수 있는 좋은 시작점
#
# * 단점
#   - (수백 개 이상의) 많은 특징을 가진 데이터 셋에는 잘 작동하지 않음
#   - 특징 값 대부분이 0인 희소 데이터 셋과도 특히 잘 작동하지 않음
#
# * 주의할 점
#   - 데이터 포인트의 거리를 측정해야 하므로 특징들의 스케일이 큰 차이가 있는 경우
#     특정 특징이 거리 계산에 큰 영향을 미칠 수 있으므로 특징들이 같은 스케일을
#     갖도록 정규화할 필요가 있음

# %% [markdown]
# ### 선형 모델
# * 입력 특성에 대한 선형 함수를 만들어 예측 수행
#
# #### 선형 회귀 모델
# \begin{align*}
# \end{align*}

# %% [raw]
# * 일반화된 예측 함수의 꼴
#
#   y = w[0]*x[0] + w[1]*x[1] + ... + w[p]*x[p] + b
#
#   - x: 데이티의 특징(특성)
#   - w, b: 학습할 파라미터
#   - y: 모델이 만들어낸 예측값

# %%
mglearn.plots.plot_linear_regression_wave()

# %% [markdown]
# #### 선형회귀(최소제곱법)

# %% [raw]
# * Linear Regression
# * OLS (Ordinary Least Squares)
#
#   - 예측값과 훈련 셋의 타깃 사이의 평균제곱오차를 최소화하는 파라미터 w와 b 찾기
#
#   - MSE (Mean Squared Error)

# %%
from sklearn.linear_model import LinearRegression
X, y = mglearn.datasets.make_wave(n_samples=60)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

lr = LinearRegression().fit(X_train, y_train)

# %%
print("lr.coef_: {}".format(lr.coef_))
print("lr.intercept_: {}".format(lr.intercept_))

# %% [raw]
# cf.) scikit-learn에서 훈련 데이터에서 유도된 속성은 항상 끝에 밑줄을 붙임

# %%
print("훈련 세트 점수: {:.2f}".format(lr.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lr.score(X_test, y_test)))

# %% [raw]
# * R^2 값: 그리 높지 않은 점수
#   - 훈련 셋과 테스트 셋의 점수가 비슷
#   ==> 과소적합
#
# * 특징이 많은 고차원 데이터 셋에서는 선형 모델의 성능 향상 가능성 높음
#   ==> 과대적합 가능성 높아짐
#   : 보스턴 주택가격 데이터 셋을 통해 확인

# %%
X, y = mglearn.datasets.load_extended_boston()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
lr = LinearRegression().fit(X_train, y_train)

# %%
print("훈련 세트 점수: {:.2f}".format(lr.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lr.score(X_test, y_test)))

# %% [raw]
# * 훈련 셋에 대한 점수는 아주 높음
# * 테스트 셋에 대한 점수는 낮음
#   ==> 과대적합 되었다!!
#
# * 과대적합된 복잡한 모델을 제어할 수 있는 모델
#   : 릿지 회귀, 라쏘 회귀

# %% [markdown]
# #### 릿지 회귀

# %% [raw]
# * 가중치 w의 절댓값을 가능한 한 작게 만드는 방식
#   - w의 모든 원소가 0에 가깝게
#   - 기울기를 작게
#     ==> 모든 특징(특성)이 출력에 주는 영향을 최소한으로
#     --> 이것을 규제(Regulation)
#
# * 규제(Regulation)
#   : 과재적합이 되지 않도록 모델을 강제로 제한
#
# * L2 규제

# %%
from sklearn.linear_model import Ridge

ridge = Ridge().fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(ridge.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(ridge.score(X_test, y_test)))

# %% [raw]
# * 릿지 모델
#   : alpha 매개 변수
#     - 훈련 셋에 대해 모델을 얼마나 단순화할 지 결정하는 매개 변수
#     - alpha 값 ↑ --> 계수 w를 0에 더 가깝게
#       ==> 훈련 셋에 대한 성능 하락
#           일반화에는 도움

# %%
ridge10 = Ridge(alpha=10).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(ridge10.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(ridge10.score(X_test, y_test)))

# %%
ridge01 = Ridge(alpha=0.1).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(ridge01.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(ridge01.score(X_test, y_test)))

# %%
plt.plot(ridge10.coef_, '^', label="Ridge alpha=10")
plt.plot(ridge.coef_, 's', label="Ridge alpha=1")
plt.plot(ridge01.coef_, 'v', label="Ridge alpha=0.1")

plt.plot(lr.coef_, 'o', label="LinearRegression")
plt.xlabel("계수 목록")
plt.ylabel("계수 크기")
xlims = plt.xlim()
plt.hlines(0, xlims[0], xlims[1])
plt.xlim(xlims)
plt.ylim(-25, 25)
plt.legend()

# %% [raw]
# * 규제 효과 이해를 위한 또다른 방법
#   - alpha 값 고정
#   - 훈련 데이터 크기를 변화
#
# * 학습 곡선(Learning Curve)

# %%
mglearn.plots.plot_ridge_n_samples()

# %% [markdown]
# #### Lasso

# %% [raw]
# * 릿지처럼 계수를 0에 가깝게 만드는 방법 중의 하나
#
# * L1 규제
#   - 어떤 특징의 계수는 정말로 0
#     --> 모델에서 완전히 제외되는 특징들이 생김
#     --> 특징 선택(Feature Selection)이 자동으로 이루어짐
#
# * 일부 계수가 0
#   ==> 특징 감소
#   ==> 모델이 간단해지고 이해하기 쉬워짐
#   ==> 모델에서 가장 중요한 특징이 무엇인지 드러내줌

# %%
from sklearn.linear_model import Lasso

lasso = Lasso().fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(lasso.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lasso.score(X_test, y_test)))
print("사용한 특성의 개수: {}".format(np.sum(lasso.coef_ != 0)))

# %%
# "max_iter" 기본 값을 증가시키지 않으면 max_iter 값을 늘이라는 경고가 발생합니다
lasso001 = Lasso(alpha=0.01, max_iter=100000).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(lasso001.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lasso001.score(X_test, y_test)))
print("사용한 특성의 개수: {}".format(np.sum(lasso001.coef_ != 0)))

# %%
lasso00001 = Lasso(alpha=0.0001, max_iter=100000).fit(X_train, y_train)
print("훈련 세트 점수: {:.2f}".format(lasso00001.score(X_train, y_train)))
print("테스트 세트 점수: {:.2f}".format(lasso00001.score(X_test, y_test)))
print("사용한 특성의 개수: {}".format(np.sum(lasso00001.coef_ != 0)))

# %%
plt.plot(lasso.coef_, 's', label="Lasso alpha=1")
plt.plot(lasso001.coef_, '^', label="Lasso alpha=0.01")
plt.plot(lasso00001.coef_, 'v', label="Lasso alpha=0.0001")

plt.plot(ridge01.coef_, 'o', label="Ridge alpha=0.1")
plt.legend(ncol=2, loc=(0, 1.05))
plt.ylim(-25, 25)
plt.xlabel("계수 목록")
plt.ylabel("계수 크기")

# %% [markdown]
# #### 분류에 대한 선형 모델

# %% [raw]
# * 이진 분류
#   - 이진 분류 함수 꼴
#
#   y = w[0]*x[0] + w[1]*x[1] + ... + w[p]*x[p] + b > 0
#
#   y < 0  ==> 클래스 -1
#   y >= 0 ==> 클래스 +1

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

X, y = mglearn.datasets.make_forge()

fig, axes = plt.subplots(1, 2, figsize=(10, 3))

for model, ax in zip([LinearSVC(), LogisticRegression()], axes):
    clf = model.fit(X, y)
    mglearn.plots.plot_2d_separator(clf, X, fill=False, eps=0.5,
                                    ax=ax, alpha=.7)
    mglearn.discrete_scatter(X[:, 0], X[:, 1], y, ax=ax)
    ax.set_title("{}".format(clf.__class__.__name__))
    ax.set_xlabel("특성 0")
    ax.set_ylabel("특성 1")
axes[0].legend()

# %% [raw]
# * C 값 높아지면 규제는 감소
#   - 높은 C 값: 훈련 셋에 최대한 맞추려고 노력
#   - 낮은 C 값: 계수 벡터(w)가 0에 가까워지도록

# %%
mglearn.plots.plot_linear_svc_regularization()

# %%
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=42)
logreg = LogisticRegression().fit(X_train, y_train)
print("훈련 세트 점수: {:.3f}".format(logreg.score(X_train, y_train)))
print("테스트 세트 점수: {:.3f}".format(logreg.score(X_test, y_test)))

# %%
logreg100 = LogisticRegression(C=100).fit(X_train, y_train)
print("훈련 세트 점수: {:.3f}".format(logreg100.score(X_train, y_train)))
print("테스트 세트 점수: {:.3f}".format(logreg100.score(X_test, y_test)))

# %%
logreg001 = LogisticRegression(C=0.01).fit(X_train, y_train)
print("훈련 세트 점수: {:.3f}".format(logreg001.score(X_train, y_train)))
print("테스트 세트 점수: {:.3f}".format(logreg001.score(X_test, y_test)))

# %%
plt.plot(logreg100.coef_.T, '^', label="C=100")
plt.plot(logreg.coef_.T, 'o', label="C=1")
plt.plot(logreg001.coef_.T, 'v', label="C=0.001")
plt.xticks(range(cancer.data.shape[1]), cancer.feature_names, rotation=90)
xlims = plt.xlim()
plt.hlines(0, xlims[0], xlims[1])
plt.xlim(xlims)
plt.ylim(-5, 5)
plt.xlabel("특성")
plt.ylabel("계수 크기")
plt.legend()

# %%
for C, marker in zip([0.001, 1, 100], ['o', '^', 'v']):
    lr_l1 = LogisticRegression(C=C, penalty="l1").fit(X_train, y_train)
    print("C={:.3f} 인 l1 로지스틱 회귀의 훈련 정확도: {:.2f}".format(
          C, lr_l1.score(X_train, y_train)))
    print("C={:.3f} 인 l1 로지스틱 회귀의 테스트 정확도: {:.2f}".format(
          C, lr_l1.score(X_test, y_test)))
    plt.plot(lr_l1.coef_.T, marker, label="C={:.3f}".format(C))

plt.xticks(range(cancer.data.shape[1]), cancer.feature_names, rotation=90)
xlims = plt.xlim()
plt.hlines(0, xlims[0], xlims[1])
plt.xlim(xlims)
plt.xlabel("특성")
plt.ylabel("계수 크기")

plt.ylim(-5, 5)
plt.legend(loc=3)

# %% [markdown]
# #### 다중 클래스 분류를 위한 선형 모델
# \begin{align*}
# \end{align*}

# %% [raw]
# * 로지스틱 회귀를 제외한 많은 선형 분류 모델
#   : 이진 분류만 지원
#
# * 이진 분류 알고리즘을 다중 분류로 확장하는 방법
#   : 일대다(one-vs-rest, ovr) 방법
#     - 클래스 수만큼 이진 분류 모델을 만듦
#     - 예측 시 모든 이진 분류기가 작동하여
#       가장 높은 점수를 내는 분류기의 클래스를 예측값으로 선택

# %% [raw]
# * 3개의 클래스로 이루어진 간단한 테스트 데이터 셋

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(random_state=42)
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(["클래스 0", "클래스 1", "클래스 2"])

# %%
linear_svm = LinearSVC().fit(X, y)
print("계수 배열의 크기: ", linear_svm.coef_.shape)
print("절편 배열의 크기: ", linear_svm.intercept_.shape)

# %%
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(linear_svm.coef_, linear_svm.intercept_,
                                  mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.ylim(-10, 15)
plt.xlim(-10, 8)
plt.xlabel("특성 0")
plt.ylabel("특성 1")
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계',
            '클래스 2 경계'], loc=(1.01, 0.3))

# %%
mglearn.plots.plot_2d_classification(linear_svm, X, fill=True, alpha=.7)
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
line = np.linspace(-15, 15)
for coef, intercept, color in zip(linear_svm.coef_, linear_svm.intercept_,
                                  mglearn.cm3.colors):
    plt.plot(line, -(line * coef[0] + intercept) / coef[1], c=color)
plt.legend(['클래스 0', '클래스 1', '클래스 2', '클래스 0 경계', '클래스 1 경계',
            '클래스 2 경계'], loc=(1.01, 0.3))
plt.xlabel("특성 0")
plt.ylabel("특성 1")

# %% [markdown]
# #### 장단점과 파라미터

# %% [raw]
# * 선형 모델의 주요 매개변수
#   - 선형 회귀: alpha
#   - 선형 분류(LinearSVC, LogisticRegression): C
#
#   - alpha 값이 클수록, C 값이 작을수록 모델이 단순해짐
#   - 로그스케일로 조정(0.01, 0.1, 1, 10 등 10배씩 변경)
#
#   - 규제: L1(절대치), L2(절대치의 제곱)
#     - 기본적으로 L2 규제
#     - 중요한 특징이 많지 않다고 판단되면 L1 규제
#
# * 선형 모델의 장점
#   - 학습 속도 빠르고, 예측 속도 빠름
#   - 매우 큰 데이터 셋과 희소 데이터 셋에서도 잘 작동
#   - 수십만~수백만 개의 샘플일 경우 옵션 solver='sag' 적용
#     - sag: Stochastic Average Gradient(확률적평균경사하강법)
#     - 또는 SGDClassifier, SGDRegressor 모델 사용 (소개된 선형 모델의 대용량 처리 버전)

# %%
# 한 줄에서 모델의 객체를 생성과 학습을 한번에 실행합니다
logreg = LogisticRegression().fit(X_train, y_train)

# %%
logreg = LogisticRegression()
y_pred = logreg.fit(X_train, y_train).predict(X_test)

# %%
y_pred = LogisticRegression().fit(X_train, y_train).predict(X_test)

# %% [markdown]
# ### 나이브 베이즈 분류기

# %%
X = np.array([[0, 1, 0, 1],
              [1, 0, 1, 1],
              [0, 0, 0, 1],
              [1, 0, 1, 0]])
y = np.array([0, 1, 0, 1])

# %%
counts = {}
for label in np.unique(y):
    # 각 클래스에 대해 반복
    # 특성마다 1 이 나타난 횟수를 센다.
    counts[label] = X[y == label].sum(axis=0)
print("특성 카운트:\n{}".format(counts))

# %% [markdown]
# #### 장단점과 파라미터

# %% [markdown]
# ### 결정 트리(Decision Tree)

# %% [raw]
# * 분류와 회귀에 널리 사용됨
#
# * 결정에 다다르기 위해 예/아니오 질문을 이어 나가면서 학습
#   - 스무고개 놀이
#
#   - 곰, 매, 펭귄, 돌고래라는 네 동물을 구분하는 문제
#
#   - 트리의 노드
#     : 질문 또는 정답
#
#   - 루트 노드, 리프 노드
#
#   - 순수 노드(pure node)
#     : 타깃 값 한 종류로만 이루어진 리프 노드
#
#   - 트리의 에지
#     : 질문의 답과 다음 질문 연결

# %%
mglearn.plots.plot_animal_tree()

# %% [markdown]
# #### 결정 트리 만들기

# %% [raw]
# * 분류를 위한 2차원 데이터 셋, two_moons
#   - 각 클래스에 75개의 데이터 포인트
#
# * 결정 트리 학습
#   - 정답에 가장 빨리 도달하는 예/아니오 질문 목록 학습
#   - 실제는 예/아니오 보다 '특성 i는 값 a보다 큰가?'와 같은 질문으로 이루어짐
#   - 가능한 모든 테스트(질문)에서 타깃값에 대해 가장 많은 정보를 가진 것 선택
#     : 정보 이론(Information Theroy)의 엔트로피

# %%
mglearn.plots.plot_tree_progressive()

# %% [raw]
# * 결정 트리를 이용한 분류
#   : 새로운 데이터 포인트에 대해 루트에서부터 시작하여
#     트리를 이동하면서 최종적으로 도착하는 리프 노드의 타깃 값을
#     해당 데이터 포인트에 대한 분류값으로 결정
#
# * 결정 트리를 회귀에 사용
#   : 분류에서 한 것과 마찬가지로 새로운 데이터 포인트에 해당되는 리프 노드를 찾음
#     찾은 리프 노드의 훈련 데이터 평균값이 출력값

# %% [markdown]
# #### 결정 트리의 복잡도 제어하기

# %% [raw]
# * 모든 리프 노드가 순수 노드가 될 때까지 진행
#   => 매우 복잡한 모델, 훈련 데이터에 과대적합
#   - 예제 그림
#     클래스 1로 결정된 영역이 클래스 0에 속한 포인트들로 둘러 쌓임, 그 반대도 존재
#     --> 결정 경계가 클래스의 포인트에서 멀리 떨어진 이상치 하나에 너무 민감
#
# * 결정 트리의 과대적합 예방법
#   1. 사전 가지치기(Pre-Pruning)
#      - 트리 생성을 일찍 중단
#        - 트리의 최대 깊이 제한
#        - 리프 노드 최대 개수 제한
#        - 노드 분할하기 위한 최소 데이터 포인트 개수 지정
#
#   2. (사후) 가지치기((Post-)Pruning)
#      - 트리 생성 후 데이터 포인트가 적은 노드를 삭제하거나 병합
#
# * scikit-learn은 사전 가지치기만 지원

# %%
from sklearn.tree import DecisionTreeClassifier

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=42)
tree = DecisionTreeClassifier(random_state=0)
tree.fit(X_train, y_train)
print("훈련 세트 정확도: {:.3f}".format(tree.score(X_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(tree.score(X_test, y_test)))

# %% [raw]
# * 훈련 셋 정확도: 1.0
#   - 모든 리프 노드가 순수 노드이므로

# %% [raw]
# * 사전 가지치기 적용
#   - 트리의 깊이 제한

# %%
tree = DecisionTreeClassifier(max_depth=4, random_state=0)
tree.fit(X_train, y_train)

print("훈련 세트 정확도: {:.3f}".format(tree.score(X_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(tree.score(X_test, y_test)))

# %% [raw]
# * 훈련 셋 정확도는 감소했지만 테스트 셋 정확도는 증가

# %% [markdown]
# #### 결정 트리 분석

# %%
from sklearn.tree import export_graphviz
export_graphviz(tree, out_file="tree.dot", class_names=["악성", "양성"],
                feature_names=cancer.feature_names, impurity=False, filled=True)

# %%
import graphviz

with open("tree.dot", encoding='utf8') as f:
    dot_graph = f.read()
display(graphviz.Source(dot_graph))

# %% [markdown]
# #### 트리의 특성 중요도

# %% [raw]
# * 특성 중요도(Feature Importance)
#   : 트리를 만드는 결정에 각 특성이 얼마나 중요한지 평가
#     0 - 전혀 사용되지 않았다
#     1 - 완벽하게 타깃 클래스 예측
#     특성 중요도 전체 합은 1

# %%
print("특성 중요도:\n{}".format(tree.feature_importances_))

# %%
def plot_feature_importances_cancer(model):
    n_features = cancer.data.shape[1]
    plt.barh(range(n_features), model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), cancer.feature_names)
    plt.xlabel("특성 중요도")
    plt.ylabel("특성")
    plt.ylim(-1, n_features)

plot_feature_importances_cancer(tree)

# %%
tree = mglearn.plots.plot_tree_not_monotone()
display(tree)

# %% [raw]
# * 컴퓨터 메모리 가격 동향

# %%
import os
ram_prices = pd.read_csv(os.path.join(mglearn.datasets.DATA_PATH, "ram_price.csv"))

plt.yticks(fontname = "Arial") # 한글 폰트가 지수에 음수를 표시하지 못하므로 ytick의 폰트를 바꾸어 줍니다.
plt.semilogy(ram_prices.date, ram_prices.price)
plt.xlabel("년")
plt.ylabel("가격 ($/Mbyte)")

# %%
from sklearn.tree import DecisionTreeRegressor
# 2000년 이전을 훈련 데이터로, 2000년 이후를 테스트 데이터로 만듭니다
data_train = ram_prices[ram_prices.date < 2000]
data_test = ram_prices[ram_prices.date >= 2000]

# 가격 예측을 위해 날짜 특성만을 이용합니다
X_train = data_train.date[:, np.newaxis]
# 데이터와 타깃 사이의 관계를 간단하게 만들기 위해 로그 스케일로 바꿉니다
y_train = np.log(data_train.price)

tree = DecisionTreeRegressor().fit(X_train, y_train)
linear_reg = LinearRegression().fit(X_train, y_train)

# 예측은 전체 기간에 대해서 수행합니다
X_all = ram_prices.date[:, np.newaxis]

pred_tree = tree.predict(X_all)
pred_lr = linear_reg.predict(X_all)

# 예측한 값의 로그 스케일을 되돌립니다
price_tree = np.exp(pred_tree)
price_lr = np.exp(pred_lr)

# %%
plt.yticks(fontname = "Arial") # 한글 폰트가 지수에 음수를 표시하지 못하므로 ytick의 폰트를 바꾸어 줍니다.
plt.semilogy(data_train.date, data_train.price, label="훈련 데이터")
plt.semilogy(data_test.date, data_test.price, label="테스트 데이터")
plt.semilogy(ram_prices.date, price_tree, label="트리 예측")
plt.semilogy(ram_prices.date, price_lr, label="선형회귀 예측")
plt.legend()

# %% [markdown]
# #### 장단점과 파라미터

# %% [raw]
# * 결정 트리의 주요 파라미터
#   - 모델 복잡도 결정: 사전 가지치기 매개변수
#   - max_depth, max_leaf_nodes, min_samples_leaf, min_samples_split 중 하나만 지정해도 충분
#
# * 장점
#   - 모델의 시각화가 용이 -> 비전문가들도 이해하기 쉬움
#   - 데이터의 스케일에 구애받지 않음
#   - 특징에 대한 정규화/표준화 같은 전처리 과정 필요 없음
#     - 특징의 스케일이 다르거나 이진 특성과 연속 특성이 혼재되어도 잘 작동함
#
# * 단점
#   - 일반화 성능이 나쁨
#     - 사전 가지치기를 사용해도 과대적합되는 경향
#     - 훈련 범위 밖의 새로운 데이터를 예측(회귀)할 능력이 없음: 특히 시계열 데이터엔 맞지 않음
#       : 예) 2000년 이후의 램 가격 예측 실패
#
#   - 앙상블 방법으로 해결

# %% [markdown]
# ### 결정 트리의 앙상블
#   * 앙상블(Ensemble)
#     : 여러 머신러닝 모델을 연결하여 더 강력한 모델을 만드는 기법
#       - 랜덤 포레스트
#       - 그래디언트 부스팅
#
# #### 랜덤 포레스트

# %% [raw]
# * 결정 트리의 주요 단점(과대적합)을 회피할 수 있는 방법
#
# * 조금씩 다른 여러 결정 트리의 묶음
#
# * 아이디어
#   : 잘 작동하되 서로 다른 방향으로 과대적합된 트리를 많이 만들면 그 결과를 평균냄으로써 과대적합된 양을 줄일 수 있다.
#
# * 결정 트리 많이 만들기
#   - 각 트리는 타깃 예측을 잘 해야 함, 트리 자체의 성능이 좋아야 함
#   - 트리들끼리는 서로 구별되어야 함
#   - 트리 생성 시 무작위성을 주입
#
# * 트리를 랜덤하게 만들기
#   1. 데이터 포인트를 무작위로 선택
#   2. 분할 테스트에서 특징을 무작위로 선택

# %% [markdown]
# ##### 랜덤 포레스트 구축

# %% [raw]
# 1. 트리 개수 결정: n_estimators 옵션
#
# 2. 데이터의 부트스트랩 샘플(bootstrap sample) 생성
#   - n_samples 데이터 포인트 중에서 무작위로 데이터를 n_samples 횟수만큼 반복 추출
#   - 한 샘플이 여러 번 추출될 수 있음
#   - 원래 데이터 셋과 크기는 같으나 누락(약 36%)되거나 중복되는 데이터 포인트 존재
#
# 3. 결정 트리 생성
#   - 각 노드에서 전체 특징을 대상이 후보 특징을 무작위로 선택한 후 최선의 테스트를 찾는 방법
#   - 몇 개의 특징을 고를지 결정: max_features 매개변수
#   - max_features 값을 크게 하면 랜덤 포레스트의 트리들은 매우 비슷해짐
#                       작게 하면                          많이 달라지고 각 트리는 깊어짐

# %% [markdown]
# ##### 랜덤 포레스트 예측

# %% [raw]
# 1. 모델에 있는 모든 트리의 예측 생성
#
# 2. 회귀
#    : 예측들을 평균하여 최종 예측 결정
#
# 3. 분류
#    : 약한 투표 전략
#      - 각 알고리즘이 출력 레이블에 대한 확률 제공
#      - 트리들의 예측 확률을 평균내어 가장 높은 확률의 클래스가 예측 분류값

# %% [markdown]
# ##### 랜덤 포레스트 분석

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=100, noise=0.25, random_state=3)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

forest = RandomForestClassifier(n_estimators=5, random_state=2)
forest.fit(X_train, y_train)

# %% [raw]
# * 랜덤 포레스트로 만들어진 트리
#   : estimators_ 속성에 저장되어 있음

# %%
axes

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
for i, (ax, tree) in enumerate(zip(axes.ravel(), forest.estimators_)):
    ax.set_title("트리 {}".format(i))
    mglearn.plots.plot_tree_partition(X, y, tree, ax=ax)
    
mglearn.plots.plot_2d_separator(forest, X, fill=True, ax=axes[-1, -1], alpha=.4)
axes[-1, -1].set_title("랜덤 포레스트")
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, random_state=0)
forest = RandomForestClassifier(n_estimators=100, random_state=0)
forest.fit(X_train, y_train)

print("훈련 세트 정확도: {:.3f}".format(forest.score(X_train, y_train)))
print("테스트 세트 정확도: {:.3f}".format(forest.score(X_test, y_test)))

# %% [raw]
# * 랜덤 포레스트는 아무런 매개 변수 튜닝 없이도 괜찮은 성능을 보임

# %%
plot_feature_importances_cancer(forest)

# %% [raw]
# * 결정 트리는 'worst radius'를 가장 중요한 특징으로 판단했으나
#   랜덤 포레스트는 'worst radius'도 매우 중요한 특징이지만 'worst perimeter'를 제일 중요한 특징으로 선택
#
# * 랜덤 포레스트의 무작위성으로 인해 가능성이 있는 많은 경우를 고려
#   ==> 단일 트리보다 더 넓은 시각으로 데이터를 바라볼 수 있음

# %% [markdown]
# #### 장단점과 파라미터

# %% [raw]
# * 회귀와 분류 문제에 있어서 랜덤 포레스트는 현재 가장 널리 사용되는 머신러닝 알고리즘
#
# * 성능이 매우 뛰어남
# * 매개변수 튜닝을 많이 하지 않아도 잘 작동
# * 데이터의 스케일을 맞출 필요 없음
#
# * 단일 트리의 단점은 보완하고 장점은 그대로 갖고 있음
#
# * 주의할 점
#   - 무작위성(랜덤)
#     트리를 많이 생성할수록 random_state 값의 변화에 따른 변동이 적다
#
# * 단점
#   - 텍스트 데이터와 같이 매우 차원이 높고 희소한 데이터에는 잘 작동하지 않음
#     : 선형 모델이 더 적합함
#   - 선형 모델보다 많은 메모리 사용, 훈련과 예측이 느림
#
# * 랜덤 포레스트 속도 문제 일부 해결
#   - n_jobs: CPU의 코어 개수 지정
#             n_jobs=-1 => CPU의 모든 코어 사용
#
# * 주요 매개변수
#   - n_estimators: 클수록 좋으나 많은 메모리와 긴 훈련 시간 필요
#   - max_features: 기본값 'auto'
#     : RandomForestClassifier - sqrt(n_features)
#       RandomForestRegressor  - n_features
#   - 사전 가지치기 관련 매개변수
